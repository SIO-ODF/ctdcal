# %%
import csv
import pandas as pd
import numpy as np
import ctdcal.fit_ctd as fit_ctd
import os

# %%
salt_Dir = './data/salt/'

file_list = os.listdir(salt_Dir)
files = []
for file in file_list:
    if '.' not in file:
        files.append(file)

# %%
files
# Out:
# ['04001',
#  '02101',
#  '08201',
#  '06501',
#  '08801',
#  '00401',
#  '08601',
#  '00202',
#  '06101',
#  '02501',
#  '04401',
#  '10001',
#  '01802',
#  '01001',
#  '09601',
#  '07101',
#  '03501',
#  '11001',
#  '05401',
#  '05802',
#  '11401',
#  '05001',
#  '03101',
#  '09201',
#  '07501',
#  '09801',
#  '01401',
#  '08101',
#  '06601',
#  '00701',
#  '10701',
#  '04301',
#  '02801',
#  '02201',
#  '04901',
#  '02601',
#  '10301',
#  '04701',
#  '00301',
#  '06801',
#  '08501',
#  '06201',
#  '11901',
#  '03601',
#  '05701',
#  '11301',
#  '01301',
#  '07801',
#  '09501',
#  '07201',
#  '01901',
#  '09101',
#  '07601',
#  '01701',
#  '05301',
#  '11701',
#  '03801',
#  '03201',
#  '05901',
#  '00601',
#  '06701',
#  '08001',
#  '04801',
#  '02301',
#  '02901',
#  '10601',
#  '04201',
#  '10201',
#  '04601',
#  '02701',
#  '10801',
#  '00801',
#  '08401',
#  '06901',
#  '05601',
#  '11201',
#  '03701',
#  '11801',
#  '07301',
#  '09401',
#  '07901',
#  '01201',
#  '01601',
#  '07701',
#  '09001',
#  '03301',
#  '03901',
#  '05201',
#  '11601',
#  '02001',
#  '04101',
#  '10501',
#  '00501',
#  '08901',
#  '12001',
#  '08301',
#  '06001',
#  '08701',
#  '00101',
#  '04501',
#  '10101',
#  '02401',
#  '07001',
#  '09701',
#  '01101',
#  '11101',
#  '05501',
#  '03401',
#  '03001',
#  '11501',
#  '05101',
#  '01501',
#  '09901',
#  '07401',
#  '09301']

# %%
def salt_loader(saltpath):
    f = open(saltpath, newline='')
    saltF = csv.reader(f,delimiter=' ', quoting=csv.QUOTE_NONE, skipinitialspace='True')
    
    saltArray = []
    for row in saltF:
        saltArray.append(row)
    del saltArray[0]
         
    header = ['STNNBR','CASTNO','SAMPNO','BathTEMP','CRavg','autosalSAMPNO',\
              'Unknown','StartTime','EndTime','Attempts','Reading1','Reading2',\
              'Reading3', 'Reading4', 'Reading5','Reading6','Reading7','Reading8',\
              'Reading9', 'Reading10','Reading11','Reading12']
    f.close()
    # make all rows of Salt files the same length as header   
    for row in saltArray:
        if len(row) < len(header):
            row.extend([np.NaN]*(len(header)-len(row)))
            
    saltArray = np.array(saltArray) # change to np array
    
    saltDF = pd.DataFrame(saltArray,columns=header) # change to DataFrame
    saltDF = saltDF.apply(pd.to_numeric, errors='ignore')
    saltDF.replace(to_replace='nan', value=np.NaN,inplace=True)
    saltDF.dropna(axis=1,how='all',inplace=True)
    saltDF = saltDF[saltDF['autosalSAMPNO'] != 'worm']
    saltDF['SALNTY'] = fit_ctd.SP_salinometer((saltDF['CRavg']/2.0),saltDF['BathTEMP'])
    return saltDF

def salt_df_parser(saltDF, outdir, stn_col = 'STNNBR', cast_col = 'CASTNO'):
    stations = saltDF[stn_col].unique()
    for station in stations:
        saltStation = saltDF[saltDF[stn_col] == station]
        casts = saltStation[cast_col].unique()
        for cast in casts:
            stn_cast_salts = saltStation[saltStation[cast_col] == cast]
        # write out individual cast files
            station_string = str(station)
            cast_string = str(cast)
            if len(station_string) == 2:
                station_string = '0' + station_string
            if len(station_string) == 1:
                station_string = '00' + station_string
            if len(cast_string) == 1:
                cast_string = '0' + cast_string
            
            outfile = outdir + station_string + cast_string + '_salts.csv'
            if not os.path.exists(outfile):
                stn_cast_salts.to_csv(outfile,index=False)
            else:
                print(outfile + ' already exists...skipping')

# %%
for file in files:
    print(file)
    salt_path = salt_Dir + file
    saltDF = salt_loader(saltpath=salt_path)
    salt_df_parser(saltDF, salt_Dir)
# Out:
# 04001
# ./data/salt/04001_salts.csv already exists...skipping
# 02101
# ./data/salt/02101_salts.csv already exists...skipping
# 08201
# ./data/salt/08201_salts.csv already exists...skipping
# 06501
# ./data/salt/06501_salts.csv already exists...skipping
# 08801
# ./data/salt/08801_salts.csv already exists...skipping
# 00401
# ./data/salt/00401_salts.csv already exists...skipping
# 08601
# ./data/salt/08601_salts.csv already exists...skipping
# 00202
# ./data/salt/00202_salts.csv already exists...skipping
# 06101
# ./data/salt/06101_salts.csv already exists...skipping
# 02501
# ./data/salt/02501_salts.csv already exists...skipping
# 04401
# ./data/salt/04401_salts.csv already exists...skipping
# 10001
# ./data/salt/10001_salts.csv already exists...skipping
# 01802
# ./data/salt/01802_salts.csv already exists...skipping
# 01001
# ./data/salt/01001_salts.csv already exists...skipping
# 09601
# ./data/salt/09601_salts.csv already exists...skipping
# 07101
# ./data/salt/07101_salts.csv already exists...skipping
# 03501
# ./data/salt/03501_salts.csv already exists...skipping
# 11001
# ./data/salt/11001_salts.csv already exists...skipping
# 05401
# ./data/salt/05401_salts.csv already exists...skipping
# 05802
# ./data/salt/05802_salts.csv already exists...skipping
# 11401
# ./data/salt/11401_salts.csv already exists...skipping
# 05001
# ./data/salt/05001_salts.csv already exists...skipping
# 03101
# ./data/salt/03101_salts.csv already exists...skipping
# 09201
# ./data/salt/09201_salts.csv already exists...skipping
# 07501
# ./data/salt/07501_salts.csv already exists...skipping
# 09801
# ./data/salt/09801_salts.csv already exists...skipping
# 01401
# ./data/salt/01401_salts.csv already exists...skipping
# 08101
# ./data/salt/08101_salts.csv already exists...skipping
# 06601
# ./data/salt/06601_salts.csv already exists...skipping
# 00701
# ./data/salt/00701_salts.csv already exists...skipping
# 10701
# ./data/salt/10701_salts.csv already exists...skipping
# 04301
# ./data/salt/04301_salts.csv already exists...skipping
# 02801
# ./data/salt/02801_salts.csv already exists...skipping
# 02201
# ./data/salt/02201_salts.csv already exists...skipping
# 04901
# ./data/salt/04901_salts.csv already exists...skipping
# 02601
# ./data/salt/02601_salts.csv already exists...skipping
# 10301
# ./data/salt/10301_salts.csv already exists...skipping
# 04701
# ./data/salt/04701_salts.csv already exists...skipping
# 00301
# ./data/salt/00301_salts.csv already exists...skipping
# 06801
# ./data/salt/06801_salts.csv already exists...skipping
# 08501
# ./data/salt/08501_salts.csv already exists...skipping
# 06201
# ./data/salt/06201_salts.csv already exists...skipping
# 11901
# ./data/salt/11901_salts.csv already exists...skipping
# 03601
# ./data/salt/03601_salts.csv already exists...skipping
# 05701
# ./data/salt/05701_salts.csv already exists...skipping
# 11301
# ./data/salt/11301_salts.csv already exists...skipping
# 01301
# ./data/salt/01301_salts.csv already exists...skipping
# 07801
# ./data/salt/07801_salts.csv already exists...skipping
# 09501
# ./data/salt/09501_salts.csv already exists...skipping
# 07201
# ./data/salt/07201_salts.csv already exists...skipping
# 01901
# ./data/salt/01901_salts.csv already exists...skipping
# 09101
# ./data/salt/09101_salts.csv already exists...skipping
# 07601
# ./data/salt/07601_salts.csv already exists...skipping
# 01701
# ./data/salt/01701_salts.csv already exists...skipping
# 05301
# ./data/salt/05301_salts.csv already exists...skipping
# 11701
# ./data/salt/11701_salts.csv already exists...skipping
# 03801
# ./data/salt/03801_salts.csv already exists...skipping
# 03201
# ./data/salt/03201_salts.csv already exists...skipping
# 05901
# ./data/salt/05901_salts.csv already exists...skipping
# 00601
# ./data/salt/00601_salts.csv already exists...skipping
# 06701
# ./data/salt/06701_salts.csv already exists...skipping
# 08001
# ./data/salt/08001_salts.csv already exists...skipping
# 04801
# ./data/salt/04801_salts.csv already exists...skipping
# 02301
# ./data/salt/02301_salts.csv already exists...skipping
# 02901
# ./data/salt/02901_salts.csv already exists...skipping
# 10601
# ./data/salt/10601_salts.csv already exists...skipping
# 04201
# ./data/salt/04201_salts.csv already exists...skipping
# 10201
# ./data/salt/10201_salts.csv already exists...skipping
# 04601
# ./data/salt/04601_salts.csv already exists...skipping
# 02701
# ./data/salt/02701_salts.csv already exists...skipping
# 10801
# ./data/salt/10801_salts.csv already exists...skipping
# 00801
# ./data/salt/00801_salts.csv already exists...skipping
# 08401
# ./data/salt/08401_salts.csv already exists...skipping
# 06901
# ./data/salt/06901_salts.csv already exists...skipping
# 05601
# ./data/salt/05601_salts.csv already exists...skipping
# 11201
# ./data/salt/11201_salts.csv already exists...skipping
# 03701
# 11801
# ./data/salt/11801_salts.csv already exists...skipping
# 07301
# ./data/salt/07301_salts.csv already exists...skipping
# 09401
# ./data/salt/09401_salts.csv already exists...skipping
# 07901
# ./data/salt/07901_salts.csv already exists...skipping
# 01201
# ./data/salt/01201_salts.csv already exists...skipping
# 01601
# ./data/salt/01601_salts.csv already exists...skipping
# 07701
# ./data/salt/07701_salts.csv already exists...skipping
# 09001
# ./data/salt/09001_salts.csv already exists...skipping
# 03301
# ./data/salt/03301_salts.csv already exists...skipping
# 03901
# ./data/salt/03901_salts.csv already exists...skipping
# 05201
# ./data/salt/05201_salts.csv already exists...skipping
# 11601
# ./data/salt/11601_salts.csv already exists...skipping
# 02001
# ./data/salt/02001_salts.csv already exists...skipping
# 04101
# ./data/salt/04101_salts.csv already exists...skipping
# 10501
# ./data/salt/10501_salts.csv already exists...skipping
# 00501
# ./data/salt/00501_salts.csv already exists...skipping
# 08901
# ./data/salt/08901_salts.csv already exists...skipping
# 12001
# ./data/salt/12001_salts.csv already exists...skipping
# 08301
# ./data/salt/08301_salts.csv already exists...skipping
# 06001
# 08701
# ./data/salt/08701_salts.csv already exists...skipping
# 00101
# ./data/salt/00101_salts.csv already exists...skipping
# 04501
# ./data/salt/04501_salts.csv already exists...skipping
# 10101
# ./data/salt/10101_salts.csv already exists...skipping
# 02401
# ./data/salt/02401_salts.csv already exists...skipping
# 07001
# ./data/salt/07001_salts.csv already exists...skipping
# 09701
# ./data/salt/09701_salts.csv already exists...skipping
# 01101
# ./data/salt/01101_salts.csv already exists...skipping
# 11101
# ./data/salt/11101_salts.csv already exists...skipping
# 05501
# 03401
# ./data/salt/03401_salts.csv already exists...skipping
# 03001
# ./data/salt/03001_salts.csv already exists...skipping
# 11501
# ./data/salt/11501_salts.csv already exists...skipping
# 05101
# ./data/salt/05101_salts.csv already exists...skipping
# 01501
# ./data/salt/01501_salts.csv already exists...skipping
# 09901
# ./data/salt/09901_salts.csv already exists...skipping
# 07401
# 09301
# ./data/salt/09301_salts.csv already exists...skipping

# %%
os.path.exists()

# %%
help(pd.DataFrame.shift)
